# %% [markdown]
# # Order Matter

# %% [raw]
# .. post::
#    :tags: atag
#    :author: Denis Gomes
#
#    This is a short description of the post.

# %% [markdown]
# Here is some more text.

# %%
print("Hello World from IPython Notebook!")
# Out:
# Hello World from IPython Notebook!
